# %% [markdown]
# * 🐶 Bark is a transformer-based text-to-audio model created by Suno. Bark can generate highly  realistic, multilingual speech as well as other audio - including music, background noise and simple sound effects.
# * TTS model is an AI model that converts text to natural sounding spoken text.
# * Bark is a multilingual model. Languages supported
# * Bark is open source and available for commercial use.
# * In this notebook I use pretrained model to generate Speech from Text.

# %%
# !pip install --upgrade aiobotocore botocore
# !pip install git+https://github.com/suno-ai/bark.git
# Out:
# Requirement already satisfied: aiobotocore in /opt/conda/lib/python3.10/site-packages (2.13.0)
# Collecting aiobotocore
#   Downloading aiobotocore-2.13.1-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: botocore in /opt/conda/lib/python3.10/site-packages (1.34.106)
# Collecting botocore
#   Downloading botocore-1.34.140-py3-none-any.whl.metadata (5.7 kB)
#   Downloading botocore-1.34.131-py3-none-any.whl.metadata (5.7 kB)
# Collecting aiohttp<4.0.0,>=3.9.2 (from aiobotocore)
#   Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/conda/lib/python3.10/site-packages (from aiobotocore) (1.14.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/conda/lib/python3.10/site-packages (from aiobotocore) (0.11.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from botocore) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.10/site-packages (from botocore) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.10/site-packages (from botocore) (1.26.18)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore) (1.9.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore) (4.0.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore) (1.16.0)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp<4.0.0,>=3.9.2->aiobotocore) (3.6)
# Downloading aiobotocore-2.13.1-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Downloading botocore-1.34.131-py3-none-any.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 62.9 MB/s eta 0:00:0000:0100:01
# Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 56.3 MB/s eta 0:00:00
# Installing collected packages: botocore, aiohttp, aiobotocore
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.34.106
#     Uninstalling botocore-1.34.106:
#       Successfully uninstalled botocore-1.34.106
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.9.1
#     Uninstalling aiohttp-3.9.1:
#       Successfully uninstalled aiohttp-3.9.1
#   Attempting uninstall: aiobotocore
#     Found existing installation: aiobotocore 2.13.0
#     Uninstalling aiobotocore-2.13.0:
#       Successfully uninstalled aiobotocore-2.13.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# boto3 1.26.100 requires botocore<1.30.0,>=1.29.100, but you have botocore 1.34.131 which is incompatible.
# Successfully installed aiobotocore-2.13.1 aiohttp-3.9.5 botocore-1.34.131
# Collecting git+https://github.com/suno-ai/bark.git
#   Cloning https://github.com/suno-ai/bark.git to /tmp/pip-req-build-f0f3gasm
#   Running command git clone --filter=blob:none --quiet https://github.com/suno-ai/bark.git /tmp/pip-req-build-f0f3gasm
#   Resolved https://github.com/suno-ai/bark.git to commit f4f32d4cd480dfec1c245d258174bc9bde3c2148
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (1.26.100)
# Collecting encodec (from suno-bark==0.0.1a0)
#   Downloading encodec-0.1.1.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 3.2 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: funcy in /opt/conda/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (2.0)
# Requirement already satisfied: huggingface-hub>=0.14.1 in /opt/conda/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (0.23.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (1.11.4)
# Requirement already satisfied: tokenizers in /opt/conda/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (0.19.1)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (2.1.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (4.66.4)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (4.41.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (4.9.0)
# Collecting botocore<1.30.0,>=1.29.100 (from boto3->suno-bark==0.0.1a0)
#   Downloading botocore-1.29.165-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3->suno-bark==0.0.1a0) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from boto3->suno-bark==0.0.1a0) (0.6.2)
# Requirement already satisfied: torchaudio in /opt/conda/lib/python3.10/site-packages (from encodec->suno-bark==0.0.1a0) (2.1.2)
# Collecting einops (from encodec->suno-bark==0.0.1a0)
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers->suno-bark==0.0.1a0) (2023.12.25)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers->suno-bark==0.0.1a0) (0.4.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.10/site-packages (from botocore<1.30.0,>=1.29.100->boto3->suno-bark==0.0.1a0) (2.9.0.post0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/conda/lib/python3.10/site-packages (from botocore<1.30.0,>=1.29.100->boto3->suno-bark==0.0.1a0) (1.26.18)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->suno-bark==0.0.1a0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (2024.2.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->suno-bark==0.0.1a0) (1.3.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.100->boto3->suno-bark==0.0.1a0) (1.16.0)
# Downloading botocore-1.29.165-py3-none-any.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 1.7 MB/s eta 0:00:0000:0100:01
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.7 MB/s eta 0:00:00
# Building wheels for collected packages: suno-bark, encodec
#   Building wheel for suno-bark (pyproject.toml) ... done
#   Created wheel for suno-bark: filename=suno_bark-0.0.1a0-py3-none-any.whl size=2567357 sha256=19bd6147637530fdefd1a202a84f71224018a43f1ed762dae6f11e76919d56d8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m5rc3pr3/wheels/e6/6d/c2/107ed849afe600f905bb4049a026df3c7c5aa75d86c2721ec7
#   Building wheel for encodec (setup.py) ... done
#   Created wheel for encodec: filename=encodec-0.1.1-py3-none-any.whl size=45759 sha256=54da1342d1024150185d2b85392eb93b3d2a493415f7c73f7beff555ac20bc1b
#   Stored in directory: /root/.cache/pip/wheels/fc/36/cb/81af8b985a5f5e0815312d5e52b41263237af07b977e6bcbf3
# Successfully built suno-bark encodec
# Installing collected packages: einops, botocore, encodec, suno-bark
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.34.131
#     Uninstalling botocore-1.34.131:
#       Successfully uninstalled botocore-1.34.131
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.13.1 requires botocore<1.34.132,>=1.34.70, but you have botocore 1.29.165 which is incompatible.
# Successfully installed botocore-1.29.165 einops-0.8.0 encodec-0.1.1 suno-bark-0.0.1a0

# %%
from bark import SAMPLE_RATE, generate_audio, preload_models
from scipy.io.wavfile import write as write_wav
from IPython.display import Audio

# download and load all models
preload_models()

# generate audio from text
text_prompt = """
     [WOMAN]  Hello, my name is Prachi Sharma. I am from India and I reside in Germany. [music]
     [upbeat music] This notebook is now Indo-German.
"""
audio_array = generate_audio(text_prompt)

# save audio to disk
write_wav("bark_generation.wav", SAMPLE_RATE, audio_array)

# play text in notebook
Audio(audio_array, rate=SAMPLE_RATE)
# Out:
# 100%|██████████| 699/699 [00:07<00:00, 87.78it/s]
# 100%|██████████| 35/35 [00:32<00:00,  1.09it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
